# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], 
              'max_features':['sqrt', 'log2'], 
              'splitter':['best', 'random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3, n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
result=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004676      0.002075         0.002610        0.001450
# 1        0.003534      0.001673         0.002503        0.001304
# 2        0.003685      0.001555         0.002245        0.001001
# 3        0.002295      0.001080         0.001945        0.000915
# 4        0.006021      0.003039         0.002218        0.001029
# 5        0.003948      0.000989         0.003329        0.000363
# 6        0.004748      0.001255         0.002737        0.000876
# 7        0.004937      0.000373         0.002767        0.000552
# 8        0.022201      0.004381         0.001042        0.000057
# 9        0.015033      0.002479         0.003009        0.002765
# 10       0.017338      0.002404         0.001708        0.000875
# 11       0.011842      0.003236         0.001126        0.000443
# 12       0.004161      0.001903         0.001344        0.000776
# 13       0.002879      0.001504         0.001042        0.000526
# 14       0.003611      0.001417         0.001323        0.000654
# 15       0.002352      0.000761         0.000806        0.000017
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.730918
# 1   {'criterion': 'squared_error', 'max_features':...           0.593211
# 2   {'criterion': 'squared_error', 'max_features':...           0.579516
# 3   {'criterion': 'squared_error', 'max_features':...           0.763707
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.734809
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.662973
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.699593
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.653520
# 8   {'criterion': 'absolute_error', 'max_features'...           0.709991
# 9   {'criterion': 'absolute_error', 'max_features'...           0.783444
# 10  {'criterion': 'absolute_error', 'max_features'...           0.681631
# 11  {'criterion': 'absolute_error', 'max_features'...           0.699441
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.737955
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.692546
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.709075
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.682102
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.569776           0.742560           0.769922
# 1            0.665640           0.558496           0.545061
# 2            0.688118           0.554521           0.709187
# 3            0.469576           0.688628           0.723026
# 4            0.583898           0.664623           0.704621
# 5            0.459322           0.745520           0.642209
# 6            0.657498           0.518770           0.695683
# 7            0.587739           0.633450           0.664320
# 8            0.542559           0.706154           0.645219
# 9            0.581248           0.722513           0.707584
# 10           0.597686           0.479407           0.720447
# 11           0.553718           0.702272           0.728059
# 12           0.581922           0.732354           0.715112
# 13           0.551707           0.589592           0.658449
# 14           0.547775           0.696290           0.699766
# 15           0.559182           0.600925           0.596859
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.583689         0.679373        0.084871                3
# 1            0.657516         0.603985        0.049647               16
# 2            0.635095         0.633288        0.059776               12
# 3            0.747055         0.678398        0.107419                4
# 4            0.711362         0.679863        0.053039                2
# 5            0.618299         0.625665        0.093547               13
# 6            0.726664         0.659642        0.073806                7
# 7            0.660558         0.639917        0.028182               11
# 8            0.608116         0.642408        0.062904               10
# 9            0.464495         0.651857        0.114458                8
# 10           0.741075         0.644049        0.095833                9
# 11           0.662956         0.669289        0.061397                6
# 12           0.728302         0.699129        0.059085                1
# 13           0.559423         0.610343        0.055737               15
# 14           0.737808         0.678143        0.066797                5
# 15           0.671026         0.622019        0.046985               14

# %%
age=float(input("Enter your Age:"))
bmi= float(input("Enter your BMI:"))
children= float(input("Enter the number of Children:"))
sex_male=int(input("Sex Male 0 or 1:"))   
smoker_yes=int(input("Smoker Yes 0 or 1:"))
# Out:
# Enter your Age: 32
# Enter your BMI: 34
# Enter the number of Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age, bmi, children, sex_male, smoker_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[39836.519]
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
